# %% [markdown]
# <a href="https://colab.research.google.com/github/akhoshmani/Excel_projects/blob/main/Pandas_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **1.Give column name as Id, Movie, Year, Rating, Duration**

# %%
df=pd.read_csv("/content/movies_cleaned (12).csv",names=["id","Movies","Year","Rating","Duration"])
df
# Out:
#           id                                             Movies  Year  Rating  \
# 0          1                     The Nightmare Before Christmas  1993     3.9
# 1          2                                          The Mummy  1932     3.5
# 2          3                               Orphans of the Storm  1921     3.2
# 3          4                               The Object of Beauty  1991     2.8
# 4          5                                         Night Tide  1963     2.8
# ...      ...                                                ...   ...     ...
# 49585  49586                                  Winter Wonderland  2013     2.8
# 49586  49587                Top Gear: Series 19: Africa Special  2013     3.4
# 49587  49588  Fireplace For Your Home: Crackling Fireplace w...  2010     3.4
# 49588  49589                                    Kate Plus Ei8ht  2010     2.7
# 49589  49590                          Kate Plus Ei8ht: Season 1  2010     2.7
#
#        Duration
# ...

# %%
df.isnull().sum()
# Out:
# id          0
# Movies      0
# Year        0
# Rating      0
# Duration    0
# dtype: int64

# %% [markdown]
# **2.Display the number of rows and number of columns**

# %%
df.shape
# Out:
# (49590, 5)

# %% [markdown]
# **3.Display the five observations that have highest duration**

# %%
b=pd.DataFrame(df.sort_values(by="Duration",ascending=False).head(5))
b
# Out:
#           id                                Movies  Year  Rating  Duration
# 22216  22217  Example 8 Hour 23.976 Remote Content  2010     3.0   28813.0
# 12303  12304                 Example 8 Hour 23.976  2010     3.2   28813.0
# 2423    2424                     The Best of Youth  2003     3.9   22024.0
# 22381  22382                        Heaven's Story  2010     2.3   16736.0
# 1831    1832               Dr. Mabuse: The Gambler  1922     3.1   16422.0

# %% [markdown]
# **4.Remove if any duplicate exists and change the index accordingly**

# %%
c=pd.DataFrame(df.drop_duplicates())
c
# Out:
#           id                                             Movies  Year  Rating  \
# 0          1                     The Nightmare Before Christmas  1993     3.9
# 1          2                                          The Mummy  1932     3.5
# 2          3                               Orphans of the Storm  1921     3.2
# 3          4                               The Object of Beauty  1991     2.8
# 4          5                                         Night Tide  1963     2.8
# ...      ...                                                ...   ...     ...
# 49585  49586                                  Winter Wonderland  2013     2.8
# 49586  49587                Top Gear: Series 19: Africa Special  2013     3.4
# 49587  49588  Fireplace For Your Home: Crackling Fireplace w...  2010     3.4
# 49588  49589                                    Kate Plus Ei8ht  2010     2.7
# 49589  49590                          Kate Plus Ei8ht: Season 1  2010     2.7
#
#        Duration
# ...

# %% [markdown]
# **5.Rename the column name ‘Movie’ as Film**

# %%
a=pd.DataFrame(df.rename(columns={"Movies":"Film"}))
a
# Out:
#           id                                               Film  Year  Rating  \
# 0          1                     The Nightmare Before Christmas  1993     3.9
# 1          2                                          The Mummy  1932     3.5
# 2          3                               Orphans of the Storm  1921     3.2
# 3          4                               The Object of Beauty  1991     2.8
# 4          5                                         Night Tide  1963     2.8
# ...      ...                                                ...   ...     ...
# 49585  49586                                  Winter Wonderland  2013     2.8
# 49586  49587                Top Gear: Series 19: Africa Special  2013     3.4
# 49587  49588  Fireplace For Your Home: Crackling Fireplace w...  2010     3.4
# 49588  49589                                    Kate Plus Ei8ht  2010     2.7
# 49589  49590                          Kate Plus Ei8ht: Season 1  2010     2.7
#
#        Duration
# ...

# %% [markdown]
# **6.Display all the observation starting from index 100 upto 200**

# %%
a=pd.DataFrame(df.loc[100:200])
a
# Out:
#       id                                            Movies  Year  Rating  \
# 100  101                       The Hunchback of Notre Dame  1923     3.5
# 101  102                                          Heathers  1989     3.7
# 102  103                                Godzilla's Revenge  1969     3.3
# 103  104                                       Hard Target  1993     3.4
# 104  105                Henry: Portrait of a Serial Killer  1986     3.2
# ..   ...                                               ...   ...     ...
# 196  197                                 The Toxic Avenger  1985     3.0
# 197  198                                     The Two Jakes  1990     3.1
# 198  199  Tales from the Crypt Presents: Bordello of Blood  1996     3.3
# 199  200                               Tales from the Hood  1995     3.4
# 200  201                     Star Trek IV: The Voyage Home  1986     3.6
#
#      Duration
# 100    6750.0
# 101    6193.0
# 102    4165.0
# 103    5771.0
# ...

# %% [markdown]
# **7.Display the name and releasing year of the film with maximum duration **

# %%
a=pd.DataFrame(df.sort_values(by="Duration",ascending=False).head(1))
a
# Out:
#           id                                Movies  Year  Rating  Duration
# 22216  22217  Example 8 Hour 23.976 Remote Content  2010     3.0   28813.0

# %% [markdown]
# **8.Display the count of films released in each year.**

# %%
a=pd.DataFrame(df["Year"].value_counts())
a
# Out:
#       count
# Year
# 2011   5511
# 2010   5107
# 2009   4451
# 2012   4339
# 2008   3358
# ...     ...
# 1926      2
# 1915      1
# 1916      1
# 1918      1
# 2014      1
#
# [101 rows x 1 columns]

# %% [markdown]
# **9.Find the film released between 1986-1996 having highest duration**

# %%
a=pd.DataFrame(df[(df["Year"]>=1986) & (df["Year"]<=1996)].sort_values(by="Duration",ascending=False).head(1))
a
# Out:
#         id                       Movies  Year  Rating  Duration
# 1648  1649  Dilwale Dulhania Le Jayenge  1995     4.0   11390.0

# %% [markdown]
# **10.Find the films having duration greater than 7000 and rating above 3.5**

# %%
a=pd.DataFrame(df[(df["Duration"]>7000) & (df["Rating"]>3.5)])
a
# Out:
#           id                                             Movies  Year  Rating  \
# 13        14                               The Boys from Brazil  1978     3.6
# 35        36                                     Into the Woods  1990     4.0
# 41        42                          In the Name of the Father  1993     3.9
# 43        44                                 Do the Right Thing  1989     3.6
# 54        55                                          The Doors  1991     3.6
# ...      ...                                                ...   ...     ...
# 45029  45030                                           Salinger  2013     4.0
# 45479  45480                     Madonna: MDNA: Live from Miami  2013     3.6
# 46831  46832  WWE for All Mankind: The Life Career of Mick F...  2013     4.2
# 46897  46898                                    The Last Tycoon  2012     3.8
# 48713  48714     WWE: The Top 25 Rivalries in Wrestling History  2013     3.7
#
#        Duration
# ...

# %% [markdown]
# **11.Print the details about 5 films having less rating , display in the descending order**

# %%
a=pd.DataFrame(df.sort_values(by="Rating",ascending=True).head(5))
a
# Out:
#           id                    Movies  Year  Rating  Duration
# 42115  42116       Sun Yaar Chill Maar  2007     1.4    2628.0
# 42160  42161       Sun Yaar Chill Maar  2007     1.4    2628.0
# 40826  40827                    Lagegi  2007     1.4    2628.0
# 40934  40935                    Lagegi  2007     1.4    2628.0
# 41396  41397  Meri Toh Lag Gayi Naukri  2011     1.5    2628.0
